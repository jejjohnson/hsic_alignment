# %% [markdown]
# # Comparing HSIC versus Mutual Information measures

# %% [markdown]
# In this notebook, we will be exploring how we can estimate the HSIC parmaeter for different distributions and look at how it compares to MI measures. Normally the procedure for calculating HSIC is as follows:
#
# 1. Calculate kernel matrices for X and Y
# 2. Center both kernel matrices
# 3. Find the Frobenius norm between the kernel matrices
#
# This works well but there is no certain way to estimate the parameter for each of the kernel matrices. There is another paper that is called the Kernel Tangent Alignment (KTA). This method is different as it is calculated like so:
#
# 1. Calculate the kernel matrices for X and Y
# 2. Find the Frobenius norm between the kernel matrices
# 3. Normalize the value by the Frobenius norm of X and Y individually
#
# This works in a similar way to the HSIC method. The difference is that you do the normalization procedure. The final algorithm is the Centered Kernel Tangent Alignment (cKTA) method which is a combination of the previous two methods. The algorithm is as follows:
#
# 1. Calculate the kernel matrices for X and Y
# 2. Center both kernel matrices
# 3. Find the Frobenius norm between the kernel matrices
# 4. Normalize the value by the Frobenius norm of X and Y individually
#
# As you can see, it would appear that this method is the most complete in the sense that it incorporates all steps to ensure that our data is sufficiently scaled to a way that is directly comparable. This notebook will attempt to see which of these methods provides a good estimate for a sigma value for the kernel matrices and how do their output values compare to mutual information measures.

# %% [markdown]
# ## Code

# %%
import sys, os
import warnings
import tqdm
import random
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

# Insert path to model directory,.
path = f"{os.getcwd()}/../../src"
sys.path.insert(0, path)

# toy datasets
from data.toy import generate_dependence_data

# Kernel Dependency measure
from models.dependence import HSIC
from models.kernel import estimate_sigma, sigma_to_gamma, gamma_to_sigma

# RBIG IT measures
from models.ite_algorithms import run_rbig_models

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

warnings.filterwarnings('ignore') # get rid of annoying warnings

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Example

# %% [markdown]
# ### Data

# %%
# data params
dataset = 'line'
num_points = 1000
seed = 123
noise_x = 0.1
noise_y = 0.1

# get dataset
X, Y = generate_dependence_data(
    dataset=dataset,
    num_points=num_points,
    seed=seed,
    noise_x=noise_x,
    noise_y=noise_y
)

# plot
fig, ax = plt.subplots()

ax.scatter(X, Y)
plt.show()

# %% [markdown]
# ### HSIC Value

# %%
# hsic params
gamma = 1.0
scorer = 'tka'

# initialize HSIC calculator
clf_hsic = HSIC(gamma=gamma, scorer=scorer)

# calculate HSIC return scorer
clf_hsic.fit(X, Y);

# hsic value and kernel alignment score
hsic_val = clf_hsic.hsic_value
tka_score = clf_hsic.score(X)

print(f"HSIC: {hsic_val:.5f}")
print(f"Target Kernel Alignment Score: {tka_score:.5f}")

scorer = 'ctka'

# initialize HSIC calculator
clf_hsic = HSIC(gamma=gamma, scorer=scorer)

# calculate HSIC return scorer
clf_hsic.fit(X, Y);

# hsic value and kernel alignment score
hsic_val = clf_hsic.hsic_value
ctka_score = clf_hsic.score(X)

print(f"HSIC: {hsic_val:.5f}")
print(f"Centered Target Kernel Alignment Score: {ctka_score:.5f}")
# Out:
# HSIC: 0.00000
# Target Kernel Alignment Score: 0.96963
# HSIC: 0.00003
# Centered Target Kernel Alignment Score: 0.00168

# %% [markdown]
# ### Problem Example
#
# So here I will demonstrate one of the problems with trying to use HSIC without proper consideration of the parameters. I will vary the gamme value from 0.001 to 1000 and we'll see that the values for HSIC and cKTA will change depending upon the parameters.

# %%
init_sigma = estimate_sigma(X, method='silverman')
sigmas = np.logspace(
    np.log10(init_sigma * 0.1), 
    np.log10(init_sigma * 10), 
    100
)

gammas = sigma_to_gamma(sigmas)

scorers = {
    'hsic': [], 
    'tka': [], 
    'ctka':[]
}
hsic_values = list()

for iscorer in scorers:
    for igamma in gammas:
        
        clf_hsic = HSIC(gamma=igamma, scorer=iscorer)

        # calculate HSIC return scorer
        clf_hsic.fit(X, Y);

        # hsic value and kernel alignment score
        scorers[iscorer].append(clf_hsic.score(X))

# %%
fig, ax = plt.subplots(nrows=3)

# HSIC Values
max_idx = np.argmax(scorers['hsic'])
hsic_max = scorers['hsic'][max_idx]
gamma_max = gammas[max_idx]
print(f'Max Gamma (HSIC): {gamma_max:.4f}')

ax[0].set_xscale('log')
ax[0].plot(gammas, scorers['hsic'], )
ax[0].scatter(gamma_max, hsic_max, s=50, c='red')

# KTA values
max_idx = np.argmax(scorers['tka'])
tka_max = scorers['tka'][max_idx]
gamma_max = gammas[max_idx]
print(f'Max Gamma (KTA): {gamma_max:.4f}')

ax[1].set_xscale('log')
ax[1].plot(gammas, scorers['tka'], )
ax[1].scatter(gamma_max, tka_max, s=50, c='red')

# cKTA values
max_idx = np.argmax(scorers['ctka'])
ctka_max = scorers['ctka'][max_idx]
gamma_max = gammas[max_idx]
print(f'Max Gamma (cKTA): {gamma_max:.4f}')

ax[2].set_xscale('log')
ax[2].plot(gammas, scorers['ctka'], )
ax[2].scatter(gamma_max, ctka_max, s=50, c='red')


plt.show()
# Out:
# Max Gamma (HSIC): 5463.6880
# Max Gamma (KTA): 0.8700
# Max Gamma (cKTA): 8699.7365

# %% [markdown]
# So as you can see, there exists some space of gamma that would fit our problem and the actual value of HSIC and cKTA changes. I also don't see any direct correspondence between the two values. Neither really make sense. There is a maximum HSIC value but that doesn't necessarily mean it's the best one.

# %% [markdown]
# ## Experiment
#
# For this experiment, I would like to investigate how each of the scores measure different datasets of varying dependency/correlation structures.
#
# I will look at the following parameters:
# * $\sigma$ - the measure of spread
#     * Sigma initialization (Scott, Silverman, Mean, Median)
# * HSIC values
# * function
#
# **Note**: Technically I would need one sigma value per dataset. But for this first experiment I will keep them fixed.

# %% [markdown]
# #### Parameter I - Gammas
#
# I will vary the gamma (sigma) parameter by means of an ad-hoc initialization. I start with the mean distance between all of the points and then vary that by a factor of 2 in both directions (more and less).

# %%
sigma_init = 'mean'

sigma_x = estimate_sigma(X, method=sigma_init)
sigma_y = estimate_sigma(Y, method=sigma_init)

print(f"Estimated sigma (X): {sigma_x:.4f}")
print(f"Estimated sigma (Y): {sigma_y:.4f}")
# Out:
# Estimated sigma (X): 1.0000
# Estimated sigma (Y): 1.0000

# %%
# get parameter grid
sigmas = np.logspace(np.log10(sigma_x * 0.1), np.log10(sigma_x * 10), 100)

# convert to gammas
init_gamma = np.mean([sigma_x, sigma_y])
gamma_params = sigma_to_gamma(sigmas)

fig, ax = plt.subplots()

ax.set_yscale('log')
ax.plot(gammas)
ax.set_ylabel('Gamma Values')

plt.show()

# %% [markdown]
# #### Parameter II - Noise Values
#
# I will vary the noise parameter to something reasonable. Ranging from 0.001 to 0.5.

# %%
noise_params = np.logspace(-3, -.3, 20)


fig, ax = plt.subplots()

ax.set_yscale('log')
ax.plot(noise_params)
ax.set_ylabel('Noise Values')

plt.show()

# %% [markdown]
# ### Parameter III - Functions
#
# I will use 4 different function types to draw samples from:
#
# * Linear Function
# * Sine Function
# * Circular Function
# * Completely Random

# %%
func_params = [
    'line',
    'sine',
    'circ',
    'rand'
]

# %% [markdown]
# ## Run Experiment

# %%
# initialize results dataframe
results_df = pd.DataFrame(columns=[
    'function',
    'noise',
    'init_gamma',
    'gamma',
    'scorer',
    'value',
    'mi',
])


for ifunction in func_params:
    print(f"Function: {ifunction}")
    
    for inoise in noise_params:
        print(f"Noise: {inoise}")

        # Generate data
        num_points = 1000
        seed = 123
        noise_x = inoise
        noise_y = inoise

        # get dataset
        X, Y = generate_dependence_data(
            dataset=ifunction,
            num_points=num_points,
            seed=seed,
            noise_x=noise_x,
            noise_y=noise_y
        )
        
        # Mutual Information
        it_measure = 'mi'
        mi_score, t_ = run_rbig_models(
            X, Y, 
            measure=it_measure, 
            verbose=None, 
            random_state=123
        )
        
        
        init_sigma_x = estimate_sigma(X, method='mean')
        init_sigma_y = estimate_sigma(Y, method='mean')
        init_gamma = np.mean([init_sigma_x, init_sigma_y])
        sigmas = np.logspace(
            np.log10(np.min([init_sigma_x, init_sigma_y]) * 0.1), 
            np.log10(np.max([init_sigma_x, init_sigma_y]) * 10), 
            100
        )

        gammas = sigma_to_gamma(sigmas)

#                 with tqdm.tqdm(gamma_params, desc='Gamma Loop') as pbar_gamma:
        for igamma in gamma_params:

            # hsic params
            scorer = 'ctka'

            # initialize HSIC calculator
            clf_hsic = HSIC(gamma=igamma, scorer=scorer)

            # calculate HSIC return scorer
            clf_hsic.fit(X, Y);

            # hsic value and kernel alignment score
            hsic_score = clf_hsic.hsic_value
            tka_score = clf_hsic.score(X)

            # hsic params
            scorer = 'tka'

            # initialize HSIC calculator
            clf_hsic = HSIC(gamma=igamma, scorer=scorer)

            # calculate HSIC return scorer
            clf_hsic.fit(X, Y);

            # hsic value and kernel alignment score
            ctka_score = clf_hsic.score(X)
            
            # Save data
            results_df = results_df.append({
                'function': ifunction,
                'noise': inoise,
                'init_gamma': init_gamma,
                'gamma': igamma,
                'scorer': 'hsic',
                'value': hsic_score,
                'mi': mi_score
            }, ignore_index=True)
            
            # Save data
            results_df = results_df.append({
                'function': ifunction,
                'noise': inoise,
                'init_gamma': init_gamma,
                'gamma': igamma,
                'scorer': 'tka',
                'value': tka_score,
                'mi': mi_score
            }, ignore_index=True)

            # Save data
            results_df = results_df.append({
                'function': ifunction,
                'noise': inoise,
                'init_gamma': init_gamma,
                'gamma': igamma,
                'scorer': 'ctka',
                'value': ctka_score,
                'mi': mi_score
            }, ignore_index=True)
# Out:
# Function: line
# Noise: 0.001
# Noise: 0.0013870919878509274
# Noise: 0.001924024182760239
# Noise: 0.002668798528338159
# Noise: 0.0037018690558462057
# Noise: 0.005134832907437549
# Noise: 0.007122485584859914
# Noise: 0.009879542688342922
# Noise: 0.013703834506631679
# Noise: 0.019008479046983877
# Noise: 0.026366508987303583
# Noise: 0.036572773363888283
# Noise: 0.050729800906537274
# Noise: 0.0703669003827306
# Noise: 0.09760536373079001
# Noise: 0.13538761800225446
# Noise: 0.18779508018514912
# Noise: 0.2604890510826428
# Noise: 0.3613222756796251
# Noise: 0.5011872336272722
# Function: sine
# Noise: 0.001
# Noise: 0.0013870919878509274
# Noise: 0.001924024182760239
# Noise: 0.002668798528338159
# Noise: 0.0037018690558462057
# Noise: 0.005134832907437549
# Noise: 0.007122485584859914
# Noise: 0.009879542688342922
# Noise: 0.013703834506631679
# Noise: 0.019008479046983877
# Noise: 0.026366508987303583
# Noise: 0.036572773363888283
# Noise: 0.050729800906537274
# ...

# %%
results_df.head()
# Out:
#   function  noise  init_gamma      gamma scorer     value        mi
# 0     line  0.001         1.0  50.000000   hsic  0.000453  5.037679
# 1     line  0.001         1.0  50.000000    tka  0.004079  5.037679
# 2     line  0.001         1.0  50.000000   ctka  0.323070  5.037679
# 3     line  0.001         1.0  45.558138   hsic  0.000530  5.037679
# 4     line  0.001         1.0  45.558138    tka  0.004671  5.037679

# %% [markdown]
# ## Visualize the Results

# %%
res_noise = results_df['noise'].unique().tolist()
res_gammas = results_df['gamma'].unique().tolist()
res_lines = results_df['function'].unique().tolist()

# %%
fig, ax = plt.subplots()
ax.scatter(
    results_df[results_df['function'] == 'line']['noise'], 
    results_df[results_df['function'] == 'line']['mi'],
    label='Line'
)
plt.xscale('log')

ax.scatter(
    results_df[results_df['function'] == 'sine']['noise'], 
    results_df[results_df['function'] == 'sine']['mi'], 
    label='Sine'
)
plt.xscale('log')

ax.scatter(
    results_df[results_df['function'] == 'circ']['noise'], 
    results_df[results_df['function'] == 'circ']['mi'], 
    label='Circle'
)

plt.xscale('log')

ax.scatter(
    results_df[results_df['function'] == 'rand']['noise'], 
    results_df[results_df['function'] == 'rand']['mi'], 
    label='Random'
)

plt.xscale('log')

ax.set_xlabel('Noise, $\sigma_y$')
ax.set_ylabel('Mutual Information, MI$(X,Y)$')
plt.legend()
ax.set_title('Experimental Parameter Space')
plt.show()

# %% [markdown]
# ### Case I - Linear Function

# %% [markdown]
# #### Visual I
#
# We want to visualize how the MI compares to each of the HSIC measures. For this, we are going to fix the noise s.t. it is
# something reasonable like 0.1. Then we would like to see how gamma varies.

# %%
def plot_res_gamma(results_df, function='line'):
    
    # Set Title stuff
    if function == 'line':
        title = 'Linear Function'
    elif function == 'sine':
        title = 'Sine Function'
    elif function == 'circ':
        title = 'Circle Function'
    elif function == 'rand':
        title = 'Random Function'
    else:
        raise ValueError(f'Unrecognized function: {line}')
    
    sub_results_df = results_df[results_df['function'] == function]
    free_params = [
    #     'gamma',
        'function'
    ]

    fixed_params = [
        'gamma',
        'value',
        'method',
        'mi'
    ]
    
    groups = sub_results_df.groupby(free_params)
    
    hue = 'gamma'

    fig, ax = plt.subplots(nrows=3, figsize=(10, 7))


    for iparams, idata in groups:

        # Plot I - HSIC
        pts = ax[0].scatter(
            x=idata[idata['scorer']=='hsic']['value'],
            y=idata[idata['scorer']=='hsic']['mi'],
            c=idata[idata['scorer']=='hsic']['gamma'],
            s=20, cmap='Spectral',
            norm=matplotlib.colors.LogNorm()
        )
        ax[0].set_xlabel('HSIC')
        ax[0].set_ylabel('Mutual Information')
        fig.colorbar(pts, ax=ax[0], label='Gamma')

        # Plot II - TKA
        pts = ax[1].scatter(
            x=idata[idata['scorer']=='tka']['value'],
            y=idata[idata['scorer']=='tka']['mi'],
            c=idata[idata['scorer']=='tka']['gamma'],
            s=20, cmap='Spectral',
            norm=matplotlib.colors.LogNorm()
        )
        ax[1].set_xlabel('KTA')
        ax[1].set_ylabel('Mutual Information')
        fig.colorbar(pts, ax=ax[1], label='Gamma')

        # Plot III - cTKA
        pts = ax[2].scatter(
            x=idata[idata['scorer']=='ctka']['value'],
            y=idata[idata['scorer']=='ctka']['mi'],
            c=idata[idata['scorer']=='ctka']['gamma'],
            s=20, cmap='Spectral',
            norm=matplotlib.colors.LogNorm()
        )
        ax[2].set_xlabel('cKTA')
        ax[2].set_ylabel('Mutual Information')
        fig.colorbar(pts, ax=ax[2], label='Gamma')
    # ax[0].get_legend().remove()
    # ax[1].get_legend().remove()
    # ax[2].get_legend().remove()
    ax[0].set_title(title)
    plt.tight_layout()
    plt.show()
    
    return None

# %% [markdown]
# ### Case I - Line Function

# %%
plot_res_gamma(results_df, function='line')

# %% [markdown]
# ### Case II - Sine Function

# %%
plot_res_gamma(results_df, function='sine')

# %% [markdown]
# ### Case III - Circle

# %%
plot_res_gamma(results_df, function='circ')

# %% [markdown]
# ### Case IV - Random Points

# %%
plot_res_gamma(results_df, function='rand')
